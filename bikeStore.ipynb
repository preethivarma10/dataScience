# %%
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt

# %%
salesData = pd.read_csv("sample_data/sales_data.csv", parse_dates=["Date"])

# %%
salesData.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit    Cost  \
# ...

# %%
salesData.shape
# Out:
# (62205, 18)

# %%
print(salesData.iloc[9])
# Out:
# Date                2016-02-22 00:00:00
# Day                                  22
# Month                          February
# Year                               2016
# Customer_Age                         35
# Age_Group                Adults (35-64)
# Customer_Gender                       M
# Country                       Australia
# State                          Victoria
# Product_Category            Accessories
# Sub_Category                 Bike Racks
# Product             Hitch Rack - 4-Bike
# Order_Quantity                     21.0
# Unit_Cost                          45.0
# Unit_Price                        120.0
# Profit                           1046.0
# Cost                              945.0
# Revenue                          1991.0
# Name: 9, dtype: object

# %%
salesData.describe()
# Out:
#                                 Date           Day          Year  \
# count                          62205  62205.000000  62205.000000
# mean   2014-11-28 14:35:34.477935872     15.610562   2014.417040
# min              2011-01-01 00:00:00      1.000000   2011.000000
# 25%              2013-12-25 00:00:00      8.000000   2013.000000
# 50%              2014-06-27 00:00:00     16.000000   2014.000000
# 75%              2016-01-11 00:00:00     23.000000   2016.000000
# max              2016-07-31 00:00:00     31.000000   2016.000000
# std                              NaN      8.784415      1.258967
#
#        Customer_Age  Order_Quantity     Unit_Cost    Unit_Price        Profit  \
# count  62205.000000    62204.000000  62204.000000  62204.000000  62204.000000
# mean      36.085781       12.114285    260.041444    457.305543    313.558228
# min        2.000000        1.000000      2.000000      5.000000    -30.000000
# ...

# %%
salesData['Unit_Cost'].describe()
# Out:
# count    62204.000000
# mean       260.041444
# std        544.561738
# min          2.000000
# 25%          4.000000
# 50%         13.000000
# 75%         42.000000
# max       2171.000000
# Name: Unit_Cost, dtype: float64

# %%
salesData['Unit_Cost'].mean()
# Out:
# np.float64(260.0414442801106)
